# %%
text =open("npl.txt")
text =text.read()
print(text)
# Out:
# Natural Language Processing (NLP) is a subfield of artificial intelligence that focuses on the interaction between computers and humans through natural language. The ultimate goal of NLP is to enable computers to understand, interpret, and generate human language in a way that is both meaningful and useful. NLP techniques are used in various applications such as language translation, sentiment analysis, speech recognition, and chatbots. By leveraging machine learning algorithms and linguistic rules, NLP systems can process and analyze large amounts of natural language data, making it possible to automate and enhance many tasks that involve human language.

# %%
import nltk
from nltk import sent_tokenize
from nltk import word_tokenize

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
sentences = sent_tokenize(text)
sentences
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 sentences = sent_tokenize(text)
#       2 sentences
#
# NameError: name 'sent_tokenize' is not defined

# %%
words = word_tokenize(text)
words
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 words = word_tokenize(text)
#       2 words
#
# NameError: name 'word_tokenize' is not defined

# %%
#Frequently repeated words top 10
from nltk.probability import FreqDist
fdist = FreqDist(words)
fdist.most_common(10)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 #Frequently repeated words top 10
# ----> 2 from nltk.probability import FreqDist
#       3 fdist = FreqDist(words)
#       4 fdist.most_common(10)
#
# ModuleNotFoundError: No module named 'nltk'

# %%
import matplotlib.pyplot as plt
fdist.plot(10)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
#removal of puncutation data cleaning started : , .
words_nopunc=[]
for w in words:
  if w.isalpha():
    words_nopunc.append(w.lower())

print(words_nopunc)
# Out:
# ['route', 'optimization', 'is', 'one', 'of', 'the', 'important', 'requirement', 'for', 'proper', 'traffic', 'management', 'in', 'cities', 'the', 'spatial', 'analysis', 'technique', 'using', 'by', 'geographical', 'information', 'system', 'gis', 'plays', 'a', 'vital', 'role', 'in', 'route', 'optimization', 'route', 'optimization', 'does', 'mean', 'only', 'shortest', 'path', 'but', 'it', 'will', 'also', 'increase', 'the', 'maximum', 'utilization', 'of', 'the', 'route', 'in', 'a', 'proper', 'way', 'the', 'necessity', 'of', 'utilization', 'of', 'advanced', 'technique', 'in', 'traffic', 'management', 'is', 'essential', 'in', 'this', 'study', 'the', 'traffic', 'volume', 'survey', 'was', 'conducted', 'in', 'all', 'important', 'locations', 'where', 'the', 'transit', 'system', 'fails', 'to', 'fulfil', 'its', 'requirement', 'in', 'the', 'study', 'area', 'global', 'positioning', 'system', 'gps', 'was', 'used', 'to', 'collect', 'the', 'spatial', 'location', 'information', 'satellite', 'image', 'w
# ...

# %%
fdist = FreqDist(words_nopunc)
fdist.plot(10)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
#and the are stopwords and have no meaning at all so find and reduce it
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stopwords = stopwords.words('english')
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
words_clean=[]

for w in words_nopunc:
  if w not in stopwords:
    words_clean.append(w)

print(words_clean)
# Out:
# ['route', 'optimization', 'one', 'important', 'requirement', 'proper', 'traffic', 'management', 'cities', 'spatial', 'analysis', 'technique', 'using', 'geographical', 'information', 'system', 'gis', 'plays', 'vital', 'role', 'route', 'optimization', 'route', 'optimization', 'mean', 'shortest', 'path', 'also', 'increase', 'maximum', 'utilization', 'route', 'proper', 'way', 'necessity', 'utilization', 'advanced', 'technique', 'traffic', 'management', 'essential', 'study', 'traffic', 'volume', 'survey', 'conducted', 'important', 'locations', 'transit', 'system', 'fails', 'fulfil', 'requirement', 'study', 'area', 'global', 'positioning', 'system', 'gps', 'used', 'collect', 'spatial', 'location', 'information', 'satellite', 'image', 'used', 'create', 'base', 'map', 'thematic', 'maps', 'causes', 'transit', 'problem', 'identified', 'alternate', 'routes', 'suggested', 'using', 'gis', 'analysis', 'traffic', 'management', 'one', 'tough', 'task', 'local', 'authorities', 'due', 'rapid', 'urbaniz
# ...

# %%
fdist = FreqDist(words_clean)
fdist.plot(10) #relevant code only no_punc
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
fdist = FreqDist(words_clean)
mostcomman = fdist.most_common(10)
mostcomman
# Out:
# [('traffic', 12),
#  ('management', 9),
#  ('spatial', 5),
#  ('gis', 5),
#  ('route', 4),
#  ('optimization', 3),
#  ('one', 3),
#  ('proper', 3),
#  ('analysis', 3),
#  ('information', 3)]

# %%
from wordcloud import WordCloud
wordcloud = WordCloud().generate(text)
plt.figure(figsize =(11,11))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
